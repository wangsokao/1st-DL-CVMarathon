# %% [markdown]
# # 作業
#
# 思考一下我們前面有提到圖片是矩陣，但維度可能會不一樣
# 例如灰階圖只有兩個維度，RGB 彩圖則有 3 個維度
#
# 假如今天我們把 RGB 3 個維度拆開來看會有甚麼不同的效果呢？

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
img_path = 'data/lena.png'
# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
img.shape
# Out:
# (512, 512, 3)

# %%
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
im_r = np.zeros_like(im_rgb)
im_g = np.zeros_like(im_rgb)
im_b = np.zeros_like(im_rgb)
im_r[:,:,0] = im_rgb[:,:,0]
im_g[:,:,1] = im_rgb[:,:,1]
im_b[:,:,2] = im_rgb[:,:,2]
plt.imshow(im_r)
plt.show()
plt.imshow(im_g)
plt.show()
plt.imshow(im_b)
plt.show()
im_r[:,:,1] = im_rgb[:,:,0]
plt.imshow(im_r)
plt.show()
im_r[:,:,2] = im_rgb[:,:,0]

plt.imshow(im_r)
plt.show()
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
img_gray2 = cv2.cvtColor(img_gray, cv2.COLOR_BGR2RGB)
'''
# 為了要不斷顯示圖片，所以使用一個迴圈
while True:
    # 顯示彩圖
    cv2.imshow('bgr', img)
    # 顯示灰圖
    cv2.imshow('gray', img_gray)

    # 直到按下 ESC 鍵才會自動關閉視窗結束程式
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break
        '''
plt.imshow(im_rgb)
plt.show()
plt.imshow(img_gray2)
plt.show()

# %%
im_bgr = cv2.imread('data/lena.jpg')

im_rgb = im_bgr[:, :, [2, 1, 0]]
Image.fromarray(im_rgb).save('data/dst/lena_swap.jpg')

im_rgb = im_bgr[:, :, ::-1]
Image.fromarray(im_rgb).save('data/dst/lena_swap_2.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3147d1e16555> in <module>
#       1 im_bgr = cv2.imread('data/lena.jpg')
#       2
# ----> 3 im_rgb = im_bgr[:, :, [2, 1, 0]]
#       4 Image.fromarray(im_rgb).save('data/dst/lena_swap.jpg')
#       5
#
# TypeError: 'NoneType' object is not subscriptable
